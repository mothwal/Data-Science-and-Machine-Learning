# %%
import pandas as pd
from datetime import datetime
from pytz import utc
import matplotlib.pyplot asplt

data = pd.read_csv("reviews.csv", parse_dates=['Timestamp'])
data.head()
# Out:
#                                          Course Name  \
# 0  The Python Mega Course: Build 10 Real World Ap...
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
# 3  The Python Mega Course: Build 10 Real World Ap...
# 4  The Python Mega Course: Build 10 Real World Ap...
#
#                   Timestamp  Rating Comment
# 0 2021-04-02 06:25:52+00:00     4.0     NaN
# 1 2021-04-02 05:12:34+00:00     4.0     NaN
# 2 2021-04-02 05:11:03+00:00     4.0     NaN
# 3 2021-04-02 03:33:24+00:00     5.0     NaN
# 4 2021-04-02 03:31:49+00:00     4.5     NaN

# %%
data.shape
# Out:
# (45000, 4)

# %%
data.columns
# Out:
# Index(['Course Name', 'Timestamp', 'Rating', 'Comment'], dtype='object')

# %%
data.hist('Rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002E689216860>]],
#       dtype=object)

# %%
data['Rating']
# Out:
# 0        4.0
# 1        4.0
# 2        4.0
# 3        5.0
# 4        4.5
# 5        4.5
# 6        4.5
# 7        5.0
# 8        5.0
# 9        5.0
# 10       4.0
# 11       5.0
# 12       4.5
# 13       4.0
# 14       4.0
# 15       4.5
# 16       5.0
# 17       3.5
# 18       4.5
# 19       4.5
# 20       4.5
# 21       4.0
# 22       5.0
# 23       5.0
# 24       4.0
# 25       5.0
# 26       4.0
# 27       5.0
# 28       5.0
# 29       4.0
#         ...
# 44970    5.0
# 44971    5.0
# 44972    5.0
# 44973    5.0
# 44974    5.0
# 44975    5.0
# 44976    5.0
# 44977    3.5
# 44978    5.0
# 44979    3.5
# 44980    5.0
# 44981    5.0
# 44982    4.0
# 44983    4.5
# 44984    4.0
# 44985    5.0
# 44986    5.0
# 44987    5.0
# 44988    5.0
# 44989    3.0
# 44990    4.5
# 44991    4.0
# 44992    5.0
# 44993    5.0
# 44994    5.0
# 44995    4.0
# 44996    5.0
# 44997    5.0
# 44998    5.0
# 44999    5.0
# Name: Rating, Length: 45000, dtype: float64

# %% [markdown]
# ##### Select mitiple column

# %%
data[['Course Name', 'Rating']]
# Out:
#                                              Course Name  Rating
# 0      The Python Mega Course: Build 10 Real World Ap...     4.0
# 1      The Python Mega Course: Build 10 Real World Ap...     4.0
# 2      The Python Mega Course: Build 10 Real World Ap...     4.0
# 3      The Python Mega Course: Build 10 Real World Ap...     5.0
# 4      The Python Mega Course: Build 10 Real World Ap...     4.5
# 5      The Python Mega Course: Build 10 Real World Ap...     4.5
# 6      The Python Mega Course: Build 10 Real World Ap...     4.5
# 7      The Python Mega Course: Build 10 Real World Ap...     5.0
# 8      The Python Mega Course: Build 10 Real World Ap...     5.0
# 9      The Python Mega Course: Build 10 Real World Ap...     5.0
# 10     The Complete Python Course: Build 10 Professio...     4.0
# 11     The Python Mega Course: Build 10 Real World Ap...     5.0
# 12     100 Python Exercises I: Evaluate and Improve Y...     4.5
# 13     The Complete Python Course: Build 10 Professio...     4.0
# 14     The Python Mega Course: Build 10 Real World Ap...     4.0
# 15     The Python Mega Course: Build 10 Real World Ap...     4.5
# 16     The Python Mega Course: Build 10 Real World Ap...     5.0
# 17     The Python Mega Course: Build 10 Real World Ap...     3.5
# 18     100 Python Exercises I: Evaluate and Improve Y...     4.5
# 19     100 Python Exercises I: Evaluate and Improve Y...     4.5
# 20     The Python Mega Course: Build 10 Real World Ap...     4.5
# 21     The Python Mega Course: Build 10 Real World Ap...     4.0
# 22     The Python Mega Course: Build 10 Real World Ap...     5.0
# 23     The Python Mega Course: Build 10 Real World Ap...     5.0
# 24     The Python Mega Course: Build 10 Real World Ap...     4.0
# 25     The Python Mega Course: Build 10 Real World Ap...     5.0
# 26     The Python Mega Course: Build 10 Real World Ap...     4.0
# 27     Interactive Data Visualization with Python and...     5.0
# 28     The Python Mega Course: Build 10 Real World Ap...     5.0
# 29     The Complete Python Course: Build 10 Professio...     4.0
# ...                                                  ...     ...
# 44970  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44971  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44972                 Python for Beginners with Examples     5.0
# 44973  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44974                 Python for Beginners with Examples     5.0
# 44975  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44976  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44977  The Python Mega Course: Build 10 Real World Ap...     3.5
# 44978                 Python for Beginners with Examples     5.0
# 44979  The Python Mega Course: Build 10 Real World Ap...     3.5
# 44980  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44981  100 Python Exercises I: Evaluate and Improve Y...     5.0
# 44982  The Python Mega Course: Build 10 Real World Ap...     4.0
# 44983  The Python Mega Course: Build 10 Real World Ap...     4.5
# 44984  The Python Mega Course: Build 10 Real World Ap...     4.0
# 44985                 Python for Beginners with Examples     5.0
# 44986                 Python for Beginners with Examples     5.0
# 44987  100 Python Exercises I: Evaluate and Improve Y...     5.0
# 44988  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44989  The Python Mega Course: Build 10 Real World Ap...     3.0
# 44990  The Python Mega Course: Build 10 Real World Ap...     4.5
# 44991  The Python Mega Course: Build 10 Real World Ap...     4.0
# 44992  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44993                        Data Processing with Python     5.0
# 44994  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44995                 Python for Beginners with Examples     4.0
# 44996  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44997  The Python Mega Course: Build 10 Real World Ap...     5.0
# 44998                 Python for Beginners with Examples     5.0
# 44999  The Python Mega Course: Build 10 Real World Ap...     5.0
#
# [45000 rows x 2 columns]

# %% [markdown]
# Selecting Raws

# %%
data.iloc[3]
# Out:
# Course Name    The Python Mega Course: Build 10 Real World Ap...
# Timestamp                              2021-04-02 03:33:24+00:00
# Rating                                                         5
# Comment                                                      NaN
# Name: 3, dtype: object

# %%
### Selecting multiple Raws

data.iloc[1:3]
# Out:
#                                          Course Name  \
# 1  The Python Mega Course: Build 10 Real World Ap...
# 2  The Python Mega Course: Build 10 Real World Ap...
#
#                    Timestamp  Rating Comment
# 1  2021-04-02 05:12:34+00:00     4.0     NaN
# 2  2021-04-02 05:11:03+00:00     4.0     NaN

# %%
#Selecting a Section
data[['Course Name', 'Rating']].iloc[1:3]
# Out:
#                                          Course Name  Rating
# 1  The Python Mega Course: Build 10 Real World Ap...     4.0
# 2  The Python Mega Course: Build 10 Real World Ap...     4.0

# %%
#Selecting a Cell
#data.at[2,'Rating']
data['Rating'].iloc[2]
# Out:
# 4.0

# %% [markdown]
# #### Filtering data based on Conditions

# %%
#One condition

#data[data['Rating']>=4].count()
data[data['Rating']>=4]
# Out:
# Course Name    38873
# Timestamp      38873
# Rating         38873
# Comment         5911
# dtype: int64

# %%
#Multiple conditions

data[data['Rating']>4 & (data['Course Name'] =="The complete python course:Build 10 Professional OOP APPs")]['Rating'].mean()
# Out:
# 4.442155555555556

# %% [markdown]
# #### Time based Filtering

# %%
data[(data['Timestamp']>=datetime(2020,7,1, tzinfo =utc))&(data['Timestamp']<=datetime(2020, 12, 31, tzinfo =utc))]
# Out:
#                                             Course Name  \
# 3065  Interactive Data Visualization with Python and...
# 3066  The Python Mega Course: Build 10 Real World Ap...
# 3067  The Python Mega Course: Build 10 Real World Ap...
# 3068  The Python Mega Course: Build 10 Real World Ap...
# 3069  The Python Mega Course: Build 10 Real World Ap...
# 3070  The Python Mega Course: Build 10 Real World Ap...
# 3071  The Python Mega Course: Build 10 Real World Ap...
# 3072  The Python Mega Course: Build 10 Real World Ap...
# 3073                 Python for Beginners with Examples
# 3074                        Data Processing with Python
# 3075  The Python Mega Course: Build 10 Real World Ap...
# 3076  The Python Mega Course: Build 10 Real World Ap...
# 3077  The Python Mega Course: Build 10 Real World Ap...
# 3078  The Python Mega Course: Build 10 Real World Ap...
# 3079  The Python Mega Course: Build 10 Real World Ap...
# 3080  The Python Mega Course: Build 10 Real World Ap...
# 3081  The Python Mega Course: Build 10 Real World Ap...
# 3082                 Python for Beginners with Examples
# 3083  The Python Mega Course: Build 10 Real World Ap...
# 3084  The Python Mega Course: Build 10 Real World Ap...
# 3085                 Python for Beginners with Examples
# 3086  The Python Mega Course: Build 10 Real World Ap...
# 3087  The Python Mega Course: Build 10 Real World Ap...
# 3088  The Python Mega Course: Build 10 Real World Ap...
# 3089  Interactive Data Visualization with Python and...
# 3090  The Python Mega Course: Build 10 Real World Ap...
# 3091  The Python Mega Course: Build 10 Real World Ap...
# 3092  The Python Mega Course: Build 10 Real World Ap...
# 3093                        Data Processing with Python
# 3094  The Python Mega Course: Build 10 Real World Ap...
# ...                                                 ...
# 9704  The Python Mega Course: Build 10 Real World Ap...
# 9705                 Python for Beginners with Examples
# 9706  The Python Mega Course: Build 10 Real World Ap...
# 9707                 Python for Beginners with Examples
# 9708  The Python Mega Course: Build 10 Real World Ap...
# 9709  The Python Mega Course: Build 10 Real World Ap...
# 9710  The Python Mega Course: Build 10 Real World Ap...
# 9711  The Python Mega Course: Build 10 Real World Ap...
# 9712  The Python Mega Course: Build 10 Real World Ap...
# 9713                        Data Processing with Python
# 9714  The Python Mega Course: Build 10 Real World Ap...
# 9715  The Python Mega Course: Build 10 Real World Ap...
# 9716  The Python Mega Course: Build 10 Real World Ap...
# 9717  The Python Mega Course: Build 10 Real World Ap...
# 9718  The Python Mega Course: Build 10 Real World Ap...
# 9719  100 Python Exercises I: Evaluate and Improve Y...
# 9720  The Python Mega Course: Build 10 Real World Ap...
# 9721  The Python Mega Course: Build 10 Real World Ap...
# 9722  The Python Mega Course: Build 10 Real World Ap...
# 9723  The Python Mega Course: Build 10 Real World Ap...
# 9724  The Python Mega Course: Build 10 Real World Ap...
# 9725  The Python Mega Course: Build 10 Real World Ap...
# 9726  The Python Mega Course: Build 10 Real World Ap...
# 9727  The Python Mega Course: Build 10 Real World Ap...
# 9728  The Python Mega Course: Build 10 Real World Ap...
# 9729  The Python Mega Course: Build 10 Real World Ap...
# 9730  The Python Mega Course: Build 10 Real World Ap...
# 9731  The Python Mega Course: Build 10 Real World Ap...
# 9732  The Python Mega Course: Build 10 Real World Ap...
# 9733  The Python Mega Course: Build 10 Real World Ap...
#
#                      Timestamp  Rating  \
# 3065 2020-12-30 23:28:34+00:00     3.0
# 3066 2020-12-30 22:59:02+00:00     4.0
# 3067 2020-12-30 22:40:10+00:00     4.5
# 3068 2020-12-30 21:56:41+00:00     4.5
# 3069 2020-12-30 21:14:34+00:00     4.5
# 3070 2020-12-30 21:09:16+00:00     5.0
# 3071 2020-12-30 20:58:29+00:00     5.0
# 3072 2020-12-30 20:09:33+00:00     5.0
# 3073 2020-12-30 19:30:23+00:00     5.0
# 3074 2020-12-30 19:02:30+00:00     4.0
# 3075 2020-12-30 18:30:32+00:00     4.5
# 3076 2020-12-30 17:59:44+00:00     4.0
# 3077 2020-12-30 16:56:59+00:00     5.0
# 3078 2020-12-30 16:54:40+00:00     4.0
# 3079 2020-12-30 16:52:34+00:00     2.5
# 3080 2020-12-30 16:38:10+00:00     5.0
# 3081 2020-12-30 16:21:13+00:00     4.0
# 3082 2020-12-30 16:07:10+00:00     4.0
# 3083 2020-12-30 15:28:06+00:00     5.0
# 3084 2020-12-30 15:27:43+00:00     4.5
# 3085 2020-12-30 14:51:37+00:00     4.0
# 3086 2020-12-30 14:13:34+00:00     5.0
# 3087 2020-12-30 12:42:48+00:00     5.0
# 3088 2020-12-30 12:35:49+00:00     4.0
# 3089 2020-12-30 11:14:47+00:00     5.0
# 3090 2020-12-30 10:06:40+00:00     4.5
# 3091 2020-12-30 09:38:08+00:00     4.5
# 3092 2020-12-30 09:29:23+00:00     5.0
# 3093 2020-12-30 07:41:47+00:00     4.0
# 3094 2020-12-30 06:45:59+00:00     5.0
# ...                        ...     ...
# 9704 2020-07-01 13:52:35+00:00     5.0
# 9705 2020-07-01 13:43:15+00:00     3.5
# 9706 2020-07-01 13:01:39+00:00     4.5
# 9707 2020-07-01 12:56:49+00:00     2.5
# 9708 2020-07-01 12:24:39+00:00     5.0
# 9709 2020-07-01 12:00:34+00:00     4.5
# 9710 2020-07-01 11:22:29+00:00     5.0
# 9711 2020-07-01 11:13:13+00:00     4.5
# 9712 2020-07-01 10:31:12+00:00     5.0
# 9713 2020-07-01 10:04:29+00:00     4.0
# 9714 2020-07-01 09:52:39+00:00     4.5
# 9715 2020-07-01 09:51:28+00:00     3.5
# 9716 2020-07-01 09:43:03+00:00     4.5
# 9717 2020-07-01 09:32:55+00:00     5.0
# 9718 2020-07-01 07:41:04+00:00     4.5
# 9719 2020-07-01 07:32:51+00:00     1.0
# 9720 2020-07-01 07:23:03+00:00     5.0
# 9721 2020-07-01 06:40:45+00:00     5.0
# 9722 2020-07-01 06:29:33+00:00     5.0
# 9723 2020-07-01 05:26:37+00:00     4.0
# 9724 2020-07-01 04:09:40+00:00     4.0
# 9725 2020-07-01 03:52:28+00:00     5.0
# 9726 2020-07-01 03:36:57+00:00     5.0
# 9727 2020-07-01 03:15:48+00:00     5.0
# 9728 2020-07-01 03:15:08+00:00     5.0
# 9729 2020-07-01 03:09:44+00:00     3.5
# 9730 2020-07-01 03:09:12+00:00     5.0
# 9731 2020-07-01 02:40:58+00:00     4.0
# 9732 2020-07-01 02:04:02+00:00     5.0
# 9733 2020-07-01 00:01:34+00:00     2.0
#
#                                                 Comment
# 3065                                                NaN
# 3066                                                NaN
# 3067                                                NaN
# 3068                                                NaN
# 3069                                                NaN
# 3070                                                NaN
# 3071                                                NaN
# 3072                                                NaN
# 3073                                                NaN
# 3074                                                NaN
# 3075                                                NaN
# 3076                                                NaN
# 3077                                                NaN
# 3078  I have no experience with python, and I so far...
# 3079                                                NaN
# 3080                                                NaN
# 3081                                                NaN
# 3082                                                NaN
# 3083  Has been a very beginner friendly ride - I am ...
# 3084                                                NaN
# 3085                                                NaN
# 3086                                                NaN
# 3087                                                NaN
# 3088                                                NaN
# 3089                                                NaN
# 3090  I really liked the practicality of this course...
# 3091                                                NaN
# 3092                                                NaN
# 3093                                                NaN
# 3094                                                NaN
# ...                                                 ...
# 9704                                                NaN
# 9705                                                NaN
# 9706                                                NaN
# 9707                                                NaN
# 9708                                                NaN
# 9709                                                NaN
# 9710                                                NaN
# 9711                                                NaN
# 9712  It makes all other lectures just look bad. I a...
# 9713                                                NaN
# 9714                                                NaN
# 9715                                                NaN
# 9716                                                NaN
# 9717                                                NaN
# 9718                                                NaN
# 9719                                                NaN
# 9720                                                NaN
# 9721  i am enjoying the course. Small videos.\nI fil...
# 9722                                                NaN
# 9723                                               good
# 9724                                                NaN
# 9725              Good start, brilliant short examples.
# 9726                                                NaN
# 9727                                                NaN
# 9728                                                NaN
# 9729                                                NaN
# 9730                                                NaN
# 9731                                                NaN
# 9732                                               nice
# 9733  Hard to follow if u have no experience program...
#
# [6669 rows x 4 columns]

# %%
# Average rating
data['Rating'].mean()
# Out:
# 4.442155555555556

# %% [markdown]
# #### Data Processing, From data to information

# %%
#Average for s particular course

data[data['Course Name']=='The Python Mega Course: Build 10 Real World Applications']['Rating'].mean()
# Out:
# 4.477270180942244

# %%
#Average rating for a particular period
data[(data['Timestamp']>=datetime(2020,7,1, tzinfo =utc))&(data['Timestamp']<=datetime(2020, 12, 31, tzinfo =utc))]['Rating'].mean()
# Out:
# 4.499250262408157

# %%
#Average rating for a particular period for a particular course
data[(data['Timestamp']>=datetime(2020,7,1, tzinfo =utc))&(data['Timestamp']<=datetime(2020, 12, 31, tzinfo =utc))&
    (data['Course Name']=='The Python Mega Course: Build 10 Real World Applications')
    ]['Rating'].mean()
# Out:
# 4.520265724857047

# %%
#Average of uncommented ratings
data[data['Comment'].isnull()]['Rating'].mean()
# Out:
# 4.433679746603492

# %%
#Average of commented ratings 
data[data['Comment'].notnull()]['Rating'].mean()
# Out:
# 4.489777908515959

# %%
# Number of uncommented rating
data[data['Comment'].isnull()]['Rating'].count()
# Out:
# 38201

# %%
# Number of commented rating
data[data['Comment'].notnull()]['Rating'].count()
# Out:
# 6799

# %%
#Number os comments contains a certaing word
data[data['Comment'].str.contains('account' , na =False)]['Rating'].count()
# Out:
# 5

# %%
#Average of commented rating with "account" in comment
data[data['Comment'].str.contains('account' , na =False)]['Rating'].mean()
# Out:
# 3.5
